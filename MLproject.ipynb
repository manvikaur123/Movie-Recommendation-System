# %%
import os
os.listdir("/content/")
# Out:
# ['.config',
#  'tmdb_5000_credits.csv.zip',
#  'sample_data',
#  'tmdb_5000_credits.csv']

# %%
import zipfile
with zipfile.ZipFile("/content/tmdb_5000_credits.csv.zip","r") as zip_ref: zip_ref.extractall("/content/")

# %%
os.listdir("/content/")
# Out:
# ['.config',
#  'tmdb_5000_credits.csv.zip',
#  'sample_data',
#  'tmdb_5000_credits.csv']

# %%
import pandas as pd

movies = pd.read_csv("/content/tmdb_5000_credits.csv")

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies = movies[['title', 'cast']]
movies.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 cast
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...

# %%
import ast
def clean_cast(text):
   name = []
   for i in ast.literal_eval(text):
    names.append(i['name'])
    return " ".join(names)

    movies['cast_clean'] = movies['cast'].apply(clean_cast)
    movies.head()

# %%
import ast
def clean_cast(text):
  names = []
  for i in ast.literal_eval(text):
    names.append(i['name'])
  return " ".join(names)
movies['cast_clean']= movies['cast'].apply(clean_cast)
movies.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                           cast_clean
# 0  Sam Worthington Zoe Saldana Sigourney Weaver S...
# 1  Johnny Depp Orlando Bloom Keira Knightley Stel...
# 2  Daniel Craig Christoph Waltz Léa Seydoux Ralph...
# 3  Christian Bale Michael Caine Gary Oldman Anne ...
# 4  Taylor Kitsch Lynn Collins Samantha Morton Wil...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english')
matrix = tfidf.fit_transform(movies['cast_clean'])

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(matrix)

# %%
def recommend(movie_name):
    movie_name = movie_name.lower()
    movies['title_lower'] = movies['title'].str.lower()

    if movie_name not in movies['title_lower'].values:
        print("Movie not found ❌")
        return

    index = movies[movies['title_lower'] == movie_name].index[0]
    scores = list(enumerate(similarity[index]))
    scores = sorted(scores, key=lambda x: x[1], reverse=True)[1:6]

    print("Recommended Movies:")
    for i in scores:
        print(movies.iloc[i[0]].title)

# %%
#1
recommend("Avatar")
# Out:
# Recommended Movies:
# The Royal Tenenbaums
# The Dark Knight
# Charlie's Angels
# Idiocracy
# Bottle Rocket

# %%
#2
movie_name = input("Enter movie name: ")
recommend(movie_name)
# Out:
# Enter movie name: gerry
# Recommended Movies:
# Chasing Amy
# 200 Cigarettes
# The Killer Inside Me
# Ocean's Eleven
# To Die For

# %%
#3
def recommend_movie():
    movie_name = input("Enter movie name: ")
    recommend(movie_name)

recommend_movie()
# Out:
# Enter movie name: hulk
# Recommended Movies:
# All the Pretty Horses
# The Finest Hours
# Battle of the Year
# The Invasion
# Far from Heaven

# %%
#4
while True:
    movie_name = input("Enter movie name (or type exit): ")

    if movie_name.lower() == "exit":
        print("Thank you for using Movie Recommendation System 🎬")
        break

    recommend(movie_name)
    print("-" * 40)
# Out:
# Enter movie name (or type exit): interstellar
# Recommended Movies:
# Gerry
# The Dark Knight Rises
# A Most Violent Year
# 88 Minutes
# Jay and Silent Bob Strike Back
# ----------------------------------------
# Enter movie name (or type exit): gerry
# Recommended Movies:
# Chasing Amy
# 200 Cigarettes
# The Killer Inside Me
# Ocean's Eleven
# To Die For
# ----------------------------------------
# Enter movie name (or type exit): harry
# Movie not found ❌
# ----------------------------------------
# Enter movie name (or type exit): die
# Movie not found ❌
# ----------------------------------------
# Enter movie name (or type exit): to die for
# Recommended Movies:
# Gerry
# Chasing Amy
# 200 Cigarettes
# Clay Pigeons
# Birth
# ----------------------------------------
# Enter movie name (or type exit): exit
# Thank you for using Movie Recommendation System 🎬

# %%
#5
def recommend(movie_name):
    movie_name = movie_name.lower()
    movies['title_lower'] = movies['title'].str.lower()

    matches = movies[movies['title_lower'].str.contains(movie_name)]

    if matches.empty:
        print("Movie not found ❌")
        return

    index = matches.index[0]
    scores = list(enumerate(similarity[index]))
    scores = sorted(scores, key=lambda x: x[1], reverse=True)[1:6]

    print("Recommended Movies:")
    for i in scores:
        print(movies.iloc[i[0]].title)

# %%
movie_name = input("Enter movie name: ")
recommend(movie_name)
# Out:
# Enter movie name: harry
# Recommended Movies:
# Harry Potter and the Order of the Phoenix
# Harry Potter and the Prisoner of Azkaban
# Harry Potter and the Goblet of Fire
# Harry Potter and the Chamber of Secrets
# Harry Potter and the Philosopher's Stone

# %%
while True:
    movie_name = input("Enter movie name (or type exit): ")

    if movie_name.lower() == "exit":
        print("Thank you for using Movie Recommendation System 🎬")
        break

    recommend(movie_name)
    print("-" * 40)
# Out:
# Enter movie name (or type exit): harry
# Recommended Movies:
# Harry Potter and the Order of the Phoenix
# Harry Potter and the Prisoner of Azkaban
# Harry Potter and the Goblet of Fire
# Harry Potter and the Chamber of Secrets
# Harry Potter and the Philosopher's Stone
# ----------------------------------------
# Enter movie name (or type exit): die
# Recommended Movies:
# Captain America: Civil War
# Avengers: Age of Ultron
# The Avengers
# All Is Lost
# Thor
# ----------------------------------------
# Enter movie name (or type exit): hulk
# Recommended Movies:
# All the Pretty Horses
# The Finest Hours
# Battle of the Year
# The Invasion
# Far from Heaven
# ----------------------------------------
# Enter movie name (or type exit): exit
# Thank you for using Movie Recommendation System 🎬
